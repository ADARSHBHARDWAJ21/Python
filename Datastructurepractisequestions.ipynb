# %%
# Write a code to create a string with your name and print it.
name = "Adarsh"
print(name)
# Out:
# Adarsh

# %%
# Write a code to find the length of the string "Hello World"
code = "Hello World!"
print(len(code))
# Out:
# 12

# %%
#Write a code to slice the first 3 characters from the string "Python Programming"P
code1 = "Python Programming"
print(code1[0:3])
# Out:
# Pyt

# %%
# Write a code to convert the string "hello" to uppercase
code1 = "hello"
print(code1)
print(code1.upper())
# Out:
# hello
# HELLO

# %%
# Write a code to replace the word "apple" with "orange" in the string "I like apple"P
code1 = "I like apple"
print(code1)
print(code1.replace("apple", "orange"))
# Out:
# I like apple
# I like orange

# %%
# Write a code to create a list with numbers 1 to 5 and print
lst1 = [1,2,3,4,5]
print(lst1)
type(lst1)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
# Write a code to append the number 10 to the list [1, 2, 3, 4]
lst1 = [1,2,3,4]
print(lst1)
lst1.append(10)
print(lst1)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 10]

# %%
#Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
lst1 = [1,2,3,4,5]
print(lst1)
lst1.remove(3)
print(lst1)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 4, 5]

# %%
#Write a code to access the second element in the list ['a', 'b', 'c', 'd']P
lst1 = ['a','b', 'c', 'd']
print(lst1)
lst1[1]
# Out:
# ['a', 'b', 'c', 'd']
# 'b'

# %%
#Write a code to reverse the list [10, 20, 30, 40, 50].
lst1 = [10 , 20 , 30 , 40 ,50]
print(lst1)
reversed_list = lst1[::-1]

print(reversed_list)
# Out:
# [10, 20, 30, 40, 50]
# [50, 40, 30, 20, 10]

# %%
#Write a code to create a tuple with the elements 100, 200, 300 and print it
tupl = (100,200, 300)
print(tupl)
type(tupl)
# Out:
# (100, 200, 300)
# tuple

# %%
#Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')
typle1 = ('red', 'green', 'blue', 'yellow')
print(typle1)
typle1[-2]
# Out:
# ('red', 'green', 'blue', 'yellow')
# 'blue'

# %%
#Write a code to find the minimum number in the tuple (10, 20, 5, 15).
tuple1 = (10,20,5,15)
minimum_num = min(tuple1)
print(minimum_num)
# Out:
# 5

# %%
# Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
tuple1 = ('dog', 'cat','rabbit')
index = tuple1.index('cat')
print("Index of cat: ", index)
# Out:
# Index of cat:  1

# %%
#. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
tuple1 = ('mango', 'kiwi', 'orange','apple')
if "kiwi" in tuple1:
  print("kiwi is present in tuple1")
else:
  print("Kiwi is not present in tuple")
# Out:
# kiwi is present in tuple1

# %%
#. Write a code to create a set with the elements 'a', 'b', 'c' and print it
set = {'a' , 'b' , 'c'}
print(set)
type(set)
# Out:
# {'c', 'b', 'a'}
# set

# %%
# Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
set = {1,2,3,4,5}
print(set)
set2 = set.clear()
print(set2)
# Out:
# {1, 2, 3, 4, 5}
# None

# %%
# Write a code to remove the element 4 from the set {1, 2, 3, 4}.
set  = {1,2,3,4}
print(set)
set.remove(3)
print(set)
# Out:
# {1, 2, 3, 4}
# {1, 2, 4}

# %%
#Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
set1 = {1, 2, 3}
set2 = {3, 4, 5}

union_set = set1.union(set2)

print("Union:", union_set)
# Out:
# Union: {1, 2, 3, 4, 5}

# %%
# Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}
set1 = {1, 2, 3}
set2 = {2, 3, 4}

intersection_set = set1.intersection(set2)

print("Intersection:", intersection_set)
# Out:
# Intersection: {2, 3}

# %%
# Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
person = {
    "name": "Adarsh",
    "age": 20,
    "city": "Bhopal"
}

print(person)
# Out:
# {'name': 'Adarsh', 'age': 20, 'city': 'Bhopal'}

# %%
# Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
person = {
    "name": "john",
    "age": 25,

}
print(person)
# Out:
# {'name': 'john', 'age': 25}

# %%
# Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
person = {
    'name': 'Alice',
    'age': 30
}

print(person['name'])
# Out:
# Alice

# %%
# Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
person = {
    'name': 'Bob',
    'age': 22,
    'city': 'New York'
}

person.pop('age')

print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}
person = {
    'name': 'Alice',
    'city':'paris',

}
if 'city' in person:
  print("key 'city' exists")
else:
  print("Key 'city' does not exist")
# Out:
# key 'city' exists

# %%
# Write a code to create a list, a tuple, and a dictionary, and print them all.
lst1 = ["Adarsh" , 556 , 545]
tupl1 = (34 , 34,545,454)
dict1 = {
    "name" : "ADARSH",
    "City" : "Bhopal"
}
print(lst1)
print(tupl1)
print(dict1)
# Out:
# ['Adarsh', 556, 545]
# (34, 34, 545, 454)
# {'name': 'ADARSH', 'City': 'Bhopal'}

# %%
#. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
import random

numbers = [random.randint(1, 100) for i in range(5)]

numbers.sort()

print(numbers)
# Out:
# [11, 34, 35, 66, 94]

# %%
#. Write a code to create a list with strings and print the element at the third index.
words = ["apple", "banana", "mango", "orange", "grapes"]

print(words[3])
# Out:
# orange

# %%
# Write a code to combine two dictionaries into one and print the result.
dict1 = {
    "name": "Alice",
    "age": 25
}

dict2 = {
    "city": "Paris",
    "country": "France"
}

combined_dict = {**dict1, **dict2}

print(combined_dict)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Paris', 'country': 'France'}

# %%
#Write a code to convert a list of strings into a set.
strings = ["apple", "banana", "mango", "apple"]

string_set = __builtins__.set(strings)

print(string_set)
# Out:
# {'banana', 'mango', 'apple'}
