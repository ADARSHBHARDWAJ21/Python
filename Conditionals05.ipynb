# %% [markdown]
# Flow control is a processs to the mechanism that governs the order in which statement  and instructuions are executed . this is crucial for implementing logic in your program

# %% [markdown]
# #Conditional >>  i will play cricket when the weather is sunny
# #loop statement >> helps you to code decisions based on same preconditions
# #if
# #if else
# # if elif(elseif) else
# #nested if else

# %% [markdown]
#  #if statement
#  syntax
#  #if condition is True
#        block of code will be executed

# %%
a = 100
if a>0: # execute the if block, if the condition is true
  print("The number is greater than 0.")
# Out:
# The number is greater than 0.

# %%
a = 100
if a < 0: #execute the if block , if condition is true
  print("The number is greater than 0.")
# Out:
# The number is greater than 0.

# %%
weather = "rainy"
if weather == "rainy":
  print("I will not play cricket")
# Out:
# I will not play cricket

# %%
temp = 30
if temp>25:
  print("room temp")
# Out:
# room temp

# %%
cgpa = 8.0
if cgpa >=8:
  print("GOOD CGPA")
# Out:
# GOOD CGPA

# %% [markdown]
# #IN REAL LIFE, DECISION ARE MADE BASED ON MULTIPLE CONDITIONS

# %%
number = 42
if((number % 2 == 0) & (number % 3 == 0)):
  print("The number is divisible by 2 and 3")
# Out:
# The number is divisible by 2 and 3

# %%
grade = 8
co_cir = True
if ((grade >= 8) and (co_cir == True)):
   print("You aree all rounder")
# Out:
# You aree all rounder

# %% [markdown]
# # in real life if one condition is not fullfilles , you will do something else
# # example:: if weather is not rainy, i will go to play cricket else I will watch TV

# %%
#execute if block when the condition is true else execute else block
weather = "sunny"
if weather == "rainy":
  print("I will not play cricket")
else:
  print("I will play watvh tv")
# Out:
# I will play watvh tv

# %%
age = 21
if age >= 21:
  print("You will be served Alcohol")
else:
  print("You will be not served Alcohol")
# Out:
# You will be served Alcohol

# %%
age = 23
if age >= 18:
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
x = 1
if x > 5:
   print("x is greater than 5")
else:
  print("The no is less than 5")
# Out:
# The no is ;ess than 5

# %%
#to check no is even
num = 34
if num% 2==0:
  print("The no is even")
else:
  print("The no is odd")
# Out:
# The no is even

# %%
# pass fail
marks = 34
if marks >= 33:
  print("You are pass")
else:
  print("You are fail")
# Out:
# You are pass

# %% [markdown]
# #if else >> two conditiom
# #in real life we can multipe condition
# # syntax
# #if some condition
# #elif some condition
# #else

# %%
a  = 10
if a > 100:
  print("The num is greater then 100")
elif a < 100:
  print("The block will be executed if a is lesser than 100")
else:
  print("The block will be executed if none of the above condition is true")
# Out:
# The block will be executed if a is lesser than 100

# %%
#nested if else
x = 1
y = 6
if x > 5:
  if y > 5:
    print("X is greater then 5")
  else:
    print("X is greater than 5 but Y is less than 5")
else:
  print("X is less than 5")
# Out:
# X is less than 5

# %%
a = input("Enter a no")# by default input treats every thing as string
print("The no is" , a , type(a))
# Out:
# Enter a no4
# The no is 4 <class 'str'>

# %%
a = int(input("Enter a no "))
if a >= 100:
  print("The no is greater than 100")
elif 0<=a<100:
  print("The no is greater then 0 less then 100")
else:
  print("This is an negativr no")
# Out:
# Enter a no 34
# The no is greater then 0 less then 100
