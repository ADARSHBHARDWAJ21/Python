# %%
a = 6
a
# Out:
# 6

# %% [markdown]
# #in the memory a , memory block is created with refrence name and value

# %%
b = "Adarsh"
b
b[0]
b[2]
b[-2]
# Out:
# 's'

# %% [markdown]
# Another type of data container
# [1, 2 , 3 , 3+5j, True,  "ajay"]
# A list is a type of bag that can store anything.

# %%
list_cont = [1, 2 , 3 , 4 , 5 , 3+7j, True, "Ajay"]
list_cont[0]
list_cont[4]
type(list_cont)
# Out:
# list

# %% [markdown]
# #Mutablity - objects/container who store or value can be changed after they are created are called as mutable objects or container
# #List is a type of mutable object
#
# #String is inmutablee

# %%
list_cont[7] = "bjay"
list_cont
# Out:
# [1, 2, 3, 4, 5, (3+7j), True, 'bjay']

# %%
c = "Pwskills"
c
# Out:
# 'Pwskills'
