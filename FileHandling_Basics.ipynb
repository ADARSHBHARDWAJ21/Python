# %%
open("files.txt", 'r ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2251/1355632526.py in <cell line: 0>()
# ----> 1 open("files.txt", 'r ')
#
# ValueError: invalid mode: 'r '

# %%
file = open("file.txt", "w") #w>> write mode , if a file is not there it will create the file.txt and then read it

# %%
file.write("Hello this is my first line in the text file")
#as of now if you open the written file you will not be able to see any text in file
#to see you have to close the file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2251/1816971907.py in <cell line: 0>()
# ----> 1 file.write("Hello this is my first line in the text file")
#       2 #as of now if you open the written file you will not be able to see any text in file
#       3 #to see you have to close the file
#
# ValueError: I/O operation on closed file.

# %%
file.close()

# %%
#r >> read mode
#w >> write mode
#a >> append mode
#r+>> both reading and writting

# %%
file #file attributes
file.closed
# Out:
# True

# %%
file = open("file.txt" , "r")
file.closed
file.close()
file.closed
file.name
file.mode
file.write("This is my second line") #this will be not executed , throw an error >> file is closed >> you can not write any thing
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2251/516779539.py in <cell line: 0>()
#       5 file.name
#       6 file.mode
# ----> 7 file.write("This is my second line") #this will be not executed , throw an error >> file is closed >> you can not write any thing
#       8
#       9
#
# ValueError: I/O operation on closed file.

# %%
file = open("file.txt", "w") # it will truncat(delete) all the earlier content and make a fresh file.txt
file.close()

# %%
file = open("file.txt" , "w")
file.write("This is my first line\n")
file.write("This is my second line\n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %%
file = open("file.txt" , "w")
file.write("This is fifth line") #all earlier content will deleted
file.close() # to solve this issue we will use append so that the old lines are not deleted

# %%
file = open("file.txt" , "a") #append the new line
file.write("This is fifth line")
file.close()

# %%
file = open("file.txt" , 'r')
file.write("this is another line")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# /tmp/ipykernel_2251/2559147293.py in <cell line: 0>()
#       1 file = open("file.txt" , 'r')
# ----> 2 file.write("this is another line")
#
# UnsupportedOperation: not writable

# %%
file
# Out:
# <_io.TextIOWrapper name='file.txt' mode='r' encoding='utf-8'>

# %%
for i in file:
  print(i)
# Out:
# This is my first line
#
# This is my second line
#
# This is my third line
#
# This is my fourth line
#
# This is fifth line

# %%
print(file.read()) #here the cursor/pointer is at last position

# %%
file.read()
# Out:
# ''

# %%
file.tell() # it tellse the current position of the cursor
# Out:
# 108

# %%
file.seek(0)
# Out:
# 0

# %%
f = open("file.txt" , 'r')
print(f.readline()) #it will only read the first line
f.close()
# Out:
# This is my first line

# %%
f = open("file.txt" , 'r')
print(f.readlines()) #all the lines will be element of a list
f.close()
# Out:
# ['This is my first line\n', 'This is my second line\n', 'This is my third line\n', 'This is my fourth line\n', 'This is fifth line']

# %%
f =  open("file.txt", 'r')
f.seek(0) #it will bring the cursor to start of the file
print(f.read()) #it will read everything from starting
f.close()
# Out:
# This is my first line
# This is my second line
# This is my third line
# This is my fourth line
# This is fifth line

# %%
#present working directory
# !pwd
# Out:
# /content

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
ls
# Out:
# file.txt  sample_data/

# %%
os.path.getsize("file.txt")
# Out:
# 108

# %%
os.mkdir("/content/new_folder")

# %%
os.listdir()
# Out:
# ['.config', 'new_folder', 'sample_data']

# %%
os.rmdir("/content/new_folder")

# %%
import shutil
shutil.rmtree("test") #it will remove folder hierarchyy

# %%
os.getcwd()
# Out:
# '/content'
