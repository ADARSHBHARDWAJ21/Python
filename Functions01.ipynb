# %%
#user defined fun

# %%
print("Welcome to the office!!")

# %%
def greet(name):#passing variable inside a function
  print("Welcome to the office" ,name)

# %%
greet("Adarsh")
greet("Darsh")
greet("Ajay")
# Out:
# Welcome to the office Adarsh
# Welcome to the office Darsh
# Welcome to the office Ajay

# %%
def func():
  print("This is my first function")
func()
# Out:
# This is my first function

# %%
func() + "in Python"
# Out:
# This is my first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5205/3883059423.py in <cell line: 0>()
# ----> 1 func() + "in Python"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
type(func())
# Out:
# This is my first function
# NoneType

# %%
def func(): #return >> output of a function
  return "This is my first function"

func()
# Out:
# 'This is my first function'

# %%
func() + " in Python"
# Out:
# 'This is my first function in Python'

# %%
def func():
  return "this is my first function" , 1,2.2,True, (3+7j)

# %%
a = func()
type(a)
# Out:
# tuple

# %%
a, b, c, d , e = func()

# %%
a
# Out:
# 'this is my first function'

# %%
b
# Out:
# 1

# %%
c
# Out:
# 2.2

# %%
d
# Out:
# True

# %%
e
# Out:
# (3+7j)

# %%
a = func()
a
# Out:
# ('this is my first function', 1, 2.2, True, (3+7j))

# %%
a[0]
# Out:
# 'this is my first function'

# %%
a[1]
# Out:
# 1

# %%
a[2]
# Out:
# 2.2

# %%
a[3]
# Out:
# True

# %%
a[4]
# Out:
# (3+7j)

# %%
def func():
  calc = 2+3+6*5
  return calc

# %%
func()
# Out:
# 35

# %%
type(func())
# Out:
# int

# %%
def square_no(a):
  return a*a

# %%
square_no(5)
# Out:
# 25

# %%
square_no(1000)
# Out:
# 1000000

# %%
def square_no(args):
  return args*args

square_no(106)
# Out:
# 11236

# %%
def addition(a,b):
  return a+b

# %%
addition(5,6)
# Out:
# 11

# %%
addition(11, 20)
# Out:
# 31

# %%
addition("pw" , "skills")
# Out:
# 'pwskills'

# %%
addition([1,2,3] , [4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
addition(5,6)
# Out:
# 11

# %%
addition("skills" , "pw")
# Out:
# 'skillspw'

# %%
# a and b are positional arguments >> it maintains order

addition(b="skills" , a="pw")
# Out:
# 'pwskills'

# %%
def sum1(a, b, c):
  return a+b+c

# %%
sum1(1, 2 ,3)
# Out:
# 6

# %%
#default argument
def sum1(c, b, a=0):
  return a+b+c

# %%
sum1(b=3 , c=5)
# Out:
# 8

# %%
def sum1(a , b , c=0):
  return a+b+c

# %%
sum1(5,6)
# Out:
# 11

# %%
def add_two_number():
  a = int(input("Enter the first number: "))
  b = int(input("Enter the second number: "))
  return a+b

# %%
add_two_number()
# Out:
# Enter the first number: 43
# Enter the second number: 54
# 97

# %%
#wa function that takes list as input and return all numeric values in a list
def only_numeric(a):
  n = []
  for i in a:
    if type(i) == int or type(i) == float:
      n.append(i)
  return n

# %%
def sum1(a,b):
  return a+b

# %%
sum1(2,3)
# Out:
# 5
