# %%
for i in "pwskills":
  print(i)
# Out:
# p
# w
# s
# k
# i
# l
# l
# s

# %%
for i in ["Apple", "Banana", "Potato", 1,2]:
  print(i)
# Out:
# Apple
# Banana
# Potato
# 1
# 2

# %%
#iterablee>>
# an any python object/sequential str/data structure that is capable of returning members one at a time

# %%
lis = [1,2,"Ajay"]
#list is an iterable object
for i in lis:
  print(i)
# Out:
# 1
# 2
# Ajay

# %%
s = "pwskills" # how python decided that s should be iterated>> comes the concept of iteration
for i in s:
  print(i)
# Out:
# p
# w
# s
# k
# i
# l
# l
# s

# %%
#python>> can i prepare s for iteration
iter(s) #iterator object>> ready to be iterated

# %%
d = iter({"name": "Ajay"})

# %%
#generator functionn

# %%
#regular function>> takes a list and gives square of the list
def square_number(n):
  result = []
  for i in n:
    result.append(i ** 2)
  return result
square_number([5 , 10, 15])
# Out:
# [25, 100, 225]
