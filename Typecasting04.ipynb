# %%
a = 5
a
type(a)
# Out:
# int

# %%
b = 5.6
type(b)
# Out:
# float

# %%
d = "Adarsh"
type(d)
# Out:
# str

# %%
2+3
# Out:
# 5

# %%
type("2")
# Out:
# str

# %%
"2"+3 ## it will throww a error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1259/444662051.py in <cell line: 0>()
# ----> 1 "2"+3
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Type casting/ type conversion >> The process the data type of a value/object
#why? While executing/ computation using operators , ther can be mismatch between the data

# %%
a = "2"
b = 3
int(a)+b
# Out:
# 5

# %%
#String to integer
a = "2"
print(type(a))
print(type(int(a)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
a = 3.4
a
# Out:
# 3.4

# %%
type(a)
# Out:
# float

# %%
int(a)
# Out:
# 3

# %%
b = 6.78
type(b)
float_value =  int(b)
type(float_value)
# Out:
# int

# %%
#int to float
a = 2
type(a)
# Out:
# int

# %%
b = 6.78
type(b)
float_value = int(b)
type(float_value)
# Out:
# int

# %% [markdown]
# #CHARACTERS CANNOT BE CONVERTED INTO FLOAT/ INTEGER
# #CHARACTERS CANNOT BE CONVERTED INTO BOOLEAN

# %%
#Integer to string
v = 89
type(v)
# Out:
# int

# %%
v
# Out:
# 89

# %%
m = str(v)
type(m)
# Out:
# str

# %% [markdown]
# #TYPECATING IS OF 2 TYPES
# 1) Implicit
# 2) Explicit

# %%
#implicit typecasting
a = 5
type(a)
# Out:
# int

# %%
2*3
# Out:
# 6

# %%
2*3.5
# Out:
# 7.0

# %%
#Explicit typecasting
a = "2"
type(a)
# Out:
# str

# %%
int(a)
# Out:
# 2

# %%
float(a)
# Out:
# 2.0

# %%
2+3
# Out:
# 5

# %%
#Concatenation
a = "Ajay"
b  = "  Kumar"
a + b #concatenation pof stringg>> meaning combine the string
# Out:
# 'Ajay  Kumar'

# %%
"100  " + "Adarsh"
# Out:
# '100  Adarsh'

# %%
#bool
bool(0)
# Out:
# False

# %%
bool(100)
# Out:
# True

# %%
bool("AJAY")
# Out:
# True

# %%
bool(" ")
# Out:
# True

# %%
bool(-5)
# Out:
# True
