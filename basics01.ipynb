# %% [markdown]
# Why python ?
# Python widely usedd in industryy.
# -> Data industry
# -> A  lot of libraries
# -> Easy to learn
# ->huge active community
# ->

# %% [markdown]
# "Print" keyword is use to print output in python.

# %%
print("Hello world!!")
# Out:
# Hello world!!

# %% [markdown]
#   Variable(identifiers) -  these are place holders where we keep variety of data which we can use to write logic.
#
#   #Numbers >> Integers/float
#   #characters >> string in python
#   #true/false >> boolean
#   #none

# %%
a = 3

# %%
a
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
b = 4.5
type(b)
# Out:
# float

# %%
c = "Adarsh"
type(c)
# Out:
# str

# %%
d = True
type(d)
# Out:
# bool

# %%
True*False
# Out:
# 0

# %%
True - False
# Out:
# 1

# %%
True/False >> it will throw an error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_6790/2794436645.py in <cell line: 0>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
f = None
type(f)
# Out:
# NoneType

# %% [markdown]
# x + iy>> Complex number

# %%
com = 5+6j
type(com)
# Out:
# complex

# %%
com.real
# Out:
# 5.0

# %%
com.imag
# Out:
# 6.0

# %% [markdown]
# Rules of defining A variablee
# ->A variable starts with letter or underscore character

# %% [markdown]
# #comments

# %%
# This is my first Line of comment
#this is my second Line of coment
a = 4

# %%
#Multiline comment
'''
This is a  multi line comments
I am teaching ds
all the students are enjoying
'''
a = 5
a
# Out:
# 5

# %% [markdown]
# #Keywords >> are predefined words that hold a special meaning and have a specefic purposee ex-

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               global              pass
# None                continue            if                  raise
# True                def                 import              return
# and                 del                 in                  try
# as                  elif                is                  while
# assert              else                lambda              with
# async               except              match               yield
# await               finally             nonlocal
# break               for                 not
# case                from                or

# %%
#indentation - A specefic way of writting python codee
if 3 > 2:
  print("greater")
# Out:
# greater

# %%
a = 3 # statement >> fundamental block of code
name = "Ajay"

#Statement can be of many types>> expression, assingment, condition, statements, loop

# %%
# assingment statement
a = 5
b = 3
a + b #expression statment
# Out:
# 8

# %% [markdown]
# #input / output
# #input actually take very value as a string

# %%
name = input("Enter your name: ")
print(name)
name
type(name)
# Out:
# Enter your name: adarsh
# adarsh
# str

# %% [markdown]
# #input actually take every value as a string
# #we can convert '2' as int
#
# #type casting > casting means to change the format

# %%
#Type casting > cast means to change the format
name = int(name)

# %%
type(name)
# Out:
# str

# %%
a = "3.5"
type(a)
# Out:
# str

# %%
float(a)
# Out:
# 3.5

# %%
type(float(a))
# Out:
# float

# %%
s = "108"
type(s)
# Out:
# str

# %%
int(s)
# Out:
# 108

# %%
float(s)
# Out:
# 108.0

# %%
a = 121
type(a)
# Out:
# int

# %%
type(str(a))
# Out:
# str

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %% [markdown]
# #Python is a case senstive language

# %% [markdown]
# #Variables cannot be keywordss
