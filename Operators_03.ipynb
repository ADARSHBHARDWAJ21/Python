# %% [markdown]
# Python operators - special keywords/symbols that are used to perform operatioons or values or variable >> manage and compute data

# %%
a = 3
b = 2
a+b
# Out:
# 5

# %% [markdown]
# #Arithmetic operators

# %%
add = a+b
add
# Out:
# 5

# %%
100-3
# Out:
# 97

# %%
3-5
# Out:
# -2

# %%
3 * 5
# Out:
# 15

# %%
21/4
# Out:
# 5.25

# %%
21%5
# Out:
# 1

# %%
2 ** 5 #2 to power 5
# Out:
# 32

# %%
4 // 3  #// floor operator bringing the value to lower side
# Out:
# 1

# %%
#comparision operator >> compare two values and return a boolean value
2 == 2
# Out:
# True

# %%
2 != 2
# Out:
# False

# %%
5 != 2
# Out:
# True

# %%
10 >= 2
# Out:
# True

# %%
10 <= 10
# Out:
# True

# %% [markdown]
# #Logical operator
# #and
# #or
# True . False

# %%
True and True
True and False
True or False
False or True
# Out:
# True

# %% [markdown]
# #ASSINGMENT OPERATOR

# %%
A = 5
B = 10
B+=7 #B = B +7
B-=10
B
# Out:
# 7

# %% [markdown]
# #MEMBER SHIP OPERATORS

# %%
#membership operators
F = "pwskills"
"ps" in F
# Out:
# False

# %%
"pw" not in F
# Out:
# False

# %%
a = ["data" , "analytics", "Science"]
"data" in a
# Out:
# True

# %% [markdown]
# #Identity operators >> compares the location of two object/variable

# %%
a = 2
b = 3
a is not b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a = 2
b = a
a is b
# Out:
# True

# %% [markdown]
# #Bitwise operators >> operationss at bit level

# %%
10 & 10
# Out:
# 10
